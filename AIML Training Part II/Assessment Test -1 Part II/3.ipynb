# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

df = pd.read_csv("amazon.csv")
data = df['Sentiment'].to_numpy().reshape(-1,1)

ohe = OneHotEncoder()
ohe.fit_transform(data)
# Out:
# 'auto'
